# %% [markdown]
# ## The Battle of The Neighborhoods
#
# This project is made for the final submission of Data Science Capstone, a course on Coursera by IBM.

# %%
import pandas as pd
import numpy as np
import folium
import pickle as pkl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
from geopy.geocoders import Nominatim

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# <b>Problem Statement: </b>The aim is to open a new Pizza Place in the city of Toronto, Canada. The constraints to be applied are:
# 1. The neighborhood should not have much competition
# 2. If the first condition is met, the place with most pedestrian volumes in the day should be selected

# %% [markdown]
# Let's start by collecting the required data
#
# #### Pedestrian Density Dataset of Toronto with Coordinates of Intersections

# %%
#df_pedestrian = pd.read_csv('pedestrian_density.csv')
df_pedestrian = pd.read_csv('pedestrian_density_neighborhood.csv')

# %% [markdown]
# Finding out the Neighborhoods of intersections

# %%
neighborhood = []

opened = False

try:
    with open('neighborhoods.pkl', 'rb') as f:
        neighborhood = pkl.load(f)
    print("Neighborhoods Loaded Successfuly..")
    opened = True
except:
    pass

if not opened:
    for lat, lng in zip(df_pedestrian['Latitude'], df_pedestrian['Longitude']):
        geolocator = Nominatim()
        g = geolocator.reverse("{}, {}".format(lat, lng), timeout=10)
        try:
            neighborhood.append(g.raw['address']['neighbourhood'])
        except KeyError:
            neighborhood.append(0)
            
    with open('neighborhoods.pkl', 'wb') as f:
        pkl.dump(neighborhoods, f)
# Out:
# C:\Users\singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9eece1a3b950> in <module>()
#      14     for lat, lng in zip(df_pedestrian['Latitude'], df_pedestrian['Longitude']):
#      15         geolocator = Nominatim()
# ---> 16         g = geolocator.reverse("{}, {}".format(lat, lng), timeout=10)
#      17         try:
#      18             neighborhood.append(g.raw['address']['neighbourhood'])
#
# C:\Users\singh\Anaconda3\lib\site-packages\geopy\geocoders\osm.py in reverse(self, query, exactly_one, timeout, language, addressdetails)
#     447
#     448         return self._parse_json(
# --> 449             self._call_geocoder(url, timeout=timeout), exactly_one
#     450         )
#     451
#
# C:\Users\singh\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# C:\Users\singh\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\Users\singh\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\Users\singh\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\Users\singh\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\Users\singh\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# C:\Users\singh\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# C:\Users\singh\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# C:\Users\singh\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# C:\Users\singh\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# C:\Users\singh\Anaconda3\lib\http\client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# C:\Users\singh\Anaconda3\lib\http\client.py in connect(self)
#    1398
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#    1402                 try:
#
# C:\Users\singh\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     399                          suppress_ragged_eofs=suppress_ragged_eofs,
#     400                          server_hostname=server_hostname,
# --> 401                          _context=self, _session=session)
#     402
#     403     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# C:\Users\singh\Anaconda3\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     806                         # non-blocking
#     807                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 808                     self.do_handshake()
#     809
#     810             except (OSError, ValueError):
#
# C:\Users\singh\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1059             if timeout == 0.0 and block:
#    1060                 self.settimeout(None)
# -> 1061             self._sslobj.do_handshake()
#    1062         finally:
#    1063             self.settimeout(timeout)
#
# C:\Users\singh\Anaconda3\lib\ssl.py in do_handshake(self)
#     681     def do_handshake(self):
#     682         """Start the SSL/TLS handshake."""
# --> 683         self._sslobj.do_handshake()
#     684         if self.context.check_hostname:
#     685             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
df_pedestrian['neighborhood'] = neighborhood

# %% [markdown]
# Selecting relevant columns and renaming them

# %%
df_pedestrian = df_pedestrian[['Main', 'Side 1 Route', 'Latitude', 'Longitude', '8 Peak Hr Pedestrian Volume', 'neighborhood']]

# %%
df_pedestrian.columns = ['main', 'side_1_route', 'latitude', 'longitude', 'pedestrian_volume', 'neighborhood']
df_pedestrian.head()
# Out:
#         main   side_1_route   latitude  longitude  pedestrian_volume  \
# 0  JARVIS ST     FRONT ST E  43.649418 -79.371446              13535
# 1  KING ST E      JARVIS ST  43.650461 -79.371924               7333
# 2  JARVIS ST  ADELAIDE ST E  43.651534 -79.372360               7083
# 3  JARVIS ST  RICHMOND ST E  43.652718 -79.372824               4369
# 4  JARVIS ST     QUEEN ST E  43.653704 -79.373238               3368
#
#    neighborhood
# 0  St. Lawrence
# 1  St. Lawrence
# 2  St. Lawrence
# 3     King East
# 4     King East

# %% [markdown]
# There were some locations for which couldn't get neighborhood names. So to solve this issue, we will consider their city district instead, and for those locations that we couldn't find the city district, we will just take the main street name for those locations.

# %%
df_neigh = df_pedestrian[df_pedestrian['neighborhood'] == '0']

# %%
city_district = []

opened = False

try:
    with open('districts.pkl', 'rb') as f:
        city_district = pkl.load(f)
    print("District Data Loaded..")
    opened = True
except:
    pass

if not opened:
    for lat, lng in zip(df_neigh['latitude'], df_neigh['longitude']):
        geolocator = Nominatim(user_agent='NeighborhoodAnalysis')
        g = geolocator.reverse("{}, {}".format(lat, lng), timeout=10)
        try:
            city_district.append(g.raw['address']['city_district'])
        except KeyError:
            city_district.append(0)
    
    with open('districts.pkl', 'wb') as f:
        pkl.dump(city_district, f)
# Out:
# District Data Loaded..

# %%
df_neigh['neighborhood'] = city_district
# Out:
# C:\Users\singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_missing = df_neigh[df_neigh['neighborhood'] == 0]

# %%
df_missing['neighborhood'] = df_neigh['main']
# Out:
# C:\Users\singh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Putting those missing neighborhoods in pedestrian dataframe

# %%
for neigh, i in zip(df_neigh['neighborhood'], df_neigh.index):
    df_pedestrian.iloc[i, -1] = neigh

for neigh, i in zip(df_missing['neighborhood'], df_missing.index):
    df_pedestrian.iloc[i, -1] = neigh

# %% [markdown]
# Drop remaining unnecessary columns

# %%
df_pedestrian.drop(['main', 'side_1_route'], axis=1, inplace=True)

# %% [markdown]
# Grouping the dataframe by neighborhoods. We will take the average of all the latitudes and longitudes of same neighborhood, and take the sum of all the number of pedestrians passing by the neighborhood.

# %%
func = {'latitude':'mean', 'longitude':'mean', 'pedestrian_volume':'sum'}

# %%
df_grouped = df_pedestrian.groupby(df_pedestrian['neighborhood']).aggregate(func)

# %%
df_grouped = df_grouped.reset_index()

# %% [markdown]
# Maximum number of people passing by..

# %%
df_grouped[df_grouped['pedestrian_volume'] == df_grouped.pedestrian_volume.max()]
# Out:
#               neighborhood   latitude  longitude  pedestrian_volume
# 76  Entertainment District  43.647398 -79.388537             267667

# %% [markdown]
# Exporting the grouped dataframe to save all the computations for later

# %%
df_grouped.to_csv('final_clean_df.csv')

# %% [markdown]
# Getting coordinates of Toronto, Ontario for visualization

# %%
geocoder = Nominatim(user_agent='NeighborhoodAnalysis')
g = geocoder.geocode('Toronto, Ontario')

t_latitude = g.latitude
t_longitude = g.longitude

print("Latitude and Logitude of Toronto, Ontario are: {}, {}".format(t_latitude, t_longitude))
# Out:
# Latitude and Logitude of Toronto, Ontario are: 43.653963, -79.387207

# %% [markdown]
# Visualizing the neighborhoods calculated so far

# %%
toronto_map = folium.Map(location=[t_latitude, t_longitude], zoom_start=11)

for lat, lng in zip(df_grouped['latitude'], df_grouped['longitude']):
    folium.CircleMarker(
    [lat, lng],
    radius=5,
    color='red',
    fill=True,
    fill_color = 'red',
    fill_opactiy = 0.3).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Normalizing pedestrian volumes for visualizing map of toronto considering the number of people passing by a neighborhood. (Red to Violet -> Max to Min number of people)

# %%
df_grouped['pedestrian_volume_normalised'] = df_grouped['pedestrian_volume']/df_grouped['pedestrian_volume'].max()

# %%
toronto_map = folium.Map(location=[t_latitude, t_longitude], zoom_start=11)

colors_array = cm.rainbow(df_grouped['pedestrian_volume_normalised'])
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat, lng, neigh, vol, color, num in zip(df_grouped['latitude'], df_grouped['longitude'], df_grouped['neighborhood'], df_grouped['pedestrian_volume_normalised'], rainbow, df_grouped['pedestrian_volume']):
    label = folium.Popup(str(neigh) + ":" + str(num), parse_html=True)
    folium.CircleMarker(
    [lat, lng],
    radius=(vol+0.2)*10,
    popup=label,
    color=color,
    fill=True,
    fill_color=color,
    fill_opactiy = 0.3).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Box plot of pedestrian volume to find out the outliers in dataset

# %%
df_grouped['pedestrian_volume'].plot(kind='box')
plt.show()

# %% [markdown]
# ## Foursquare API Data Collection

# %% [markdown]
# Foursquare Credentials

# %%
CLIENT_ID = 'RWINEW5YS0D3ONXTR4G1RPH2PAEQRTNFWMSFA001KFW1LGSB'
CLIENT_SECRET = 'QQYGBVSIM1YSVXAO3ENP4NN2VJKIDICEKJSLWICYW0RDGPQ3'
VERSION = '20180605'

print('Credentials: \nClient ID: {}\nClient Secret: {}\nVersion: {}'.format(CLIENT_ID, CLIENT_SECRET, VERSION))
# Out:
# Credentials:
# Client ID: RWINEW5YS0D3ONXTR4G1RPH2PAEQRTNFWMSFA001KFW1LGSB
# Client Secret: QQYGBVSIM1YSVXAO3ENP4NN2VJKIDICEKJSLWICYW0RDGPQ3
# Version: 20180605

# %% [markdown]
# Get venues in the neighborhoods in 500 meter range

# %%
def get_nearby_venues(names, latitude, longitude, radius=500, LIMIT=100):
    
    opened = False
    try:
        nearby_venues = pd.read_csv('venue_data_toronto.csv')
        print("Venue Data Loaded..")
        opened = True
    except:
        pass
    
    if not opened:
        venues_list = []
        for name,  lat, long in zip(names, latitude, longitude):
            print('\n\nProcessing Neighborhood: ', name)
            url = "https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
            CLIENT_ID,
            CLIENT_SECRET,
            VERSION,
            lat, long,
            radius,
            LIMIT)

            results = requests.get(url).json()['response']['groups'][0]['items']

            venues_list.append([(
            name,
            lat,
            long,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])

            nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
            nearby_venues.columns=['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']

            print('Done: ', name)
        nearby_venues.to_csv('venue_data_toronto.csv', index=False)
        
    return nearby_venues

# %%
toronto_venues = get_nearby_venues(names = df_grouped['neighborhood'], 
                                   latitude = df_grouped['latitude'], 
                                   longitude = df_grouped['longitude'],
                                  radius=500)
# Out:
# Processing Neighborhood:  Agincourt
# Done:  Agincourt
#
#
# Processing Neighborhood:  Agincourt Centre
# Done:  Agincourt Centre
#
#
# Processing Neighborhood:  Agincourt North
# Done:  Agincourt North
#
#
# Processing Neighborhood:  Alderwood
# Done:  Alderwood
#
#
# Processing Neighborhood:  Alexandra Park
# Done:  Alexandra Park
#
#
# Processing Neighborhood:  Armadale
# Done:  Armadale
#
#
# Processing Neighborhood:  Armour Heights
# Done:  Armour Heights
#
#
# Processing Neighborhood:  Bathurst Quay
# Done:  Bathurst Quay
#
#
# Processing Neighborhood:  Bayview Village
# Done:  Bayview Village
#
#
# Processing Neighborhood:  Bayview Woods-Steeles
# Done:  Bayview Woods-Steeles
#
#
# Processing Neighborhood:  Beach Hill
# Done:  Beach Hill
#
#
# Processing Neighborhood:  Beaches—East York
# Done:  Beaches—East York
#
#
# Processing Neighborhood:  Beaumonde Heights
# Done:  Beaumonde Heights
#
#
# Processing Neighborhood:  Bedford Park
# Done:  Bedford Park
#
#
# Processing Neighborhood:  Bendale
# Done:  Bendale
#
#
# Processing Neighborhood:  Bennington Heights
# Done:  Bennington Heights
#
#
# Processing Neighborhood:  Birchcliff
# Done:  Birchcliff
#
#
# Processing Neighborhood:  Birchmount Park
# Done:  Birchmount Park
#
#
# Processing Neighborhood:  Bloor Street Culture Corridor
# Done:  Bloor Street Culture Corridor
#
#
# Processing Neighborhood:  Bloor West Village
# Done:  Bloor West Village
#
#
# Processing Neighborhood:  Bloorcourt Village
# Done:  Bloorcourt Village
#
#
# Processing Neighborhood:  Bloordale Gardens
# Done:  Bloordale Gardens
#
#
# Processing Neighborhood:  Bloordale Village
# Done:  Bloordale Village
#
#
# Processing Neighborhood:  Box Grove
# Done:  Box Grove
#
#
# Processing Neighborhood:  Broadview North
# Done:  Broadview North
#
#
# Processing Neighborhood:  Browns Corners
# Done:  Browns Corners
#
#
# Processing Neighborhood:  Cabbagetown
# Done:  Cabbagetown
#
#
# Processing Neighborhood:  Canary District
# Done:  Canary District
#
#
# Processing Neighborhood:  Carleton Village
# Done:  Carleton Village
#
#
# Processing Neighborhood:  Castlefield Design District
# Done:  Castlefield Design District
#
#
# Processing Neighborhood:  Cedarvale
# Done:  Cedarvale
#
#
# Processing Neighborhood:  Centennial
# Done:  Centennial
#
#
# Processing Neighborhood:  Chaplin Estates
# Done:  Chaplin Estates
#
#
# Processing Neighborhood:  Chestnut Hills
# Done:  Chestnut Hills
#
#
# Processing Neighborhood:  Chinatown
# Done:  Chinatown
#
#
# Processing Neighborhood:  Chinatown East
# Done:  Chinatown East
#
#
# Processing Neighborhood:  Christie Pits
# Done:  Christie Pits
#
#
# Processing Neighborhood:  Church-Wellesley Village
# Done:  Church-Wellesley Village
#
#
# Processing Neighborhood:  CityPlace
# Done:  CityPlace
#
#
# Processing Neighborhood:  Clairlea
# Done:  Clairlea
#
#
# Processing Neighborhood:  Clarks Corners
# Done:  Clarks Corners
#
#
# Processing Neighborhood:  Cliffcrest
# Done:  Cliffcrest
#
#
# Processing Neighborhood:  Cliffside
# Done:  Cliffside
#
#
# Processing Neighborhood:  Cloverdale
# Done:  Cloverdale
#
#
# Processing Neighborhood:  Concord Park Place
# Done:  Concord Park Place
#
#
# Processing Neighborhood:  Corktown
# Done:  Corktown
#
#
# Processing Neighborhood:  Corso Italia
# Done:  Corso Italia
#
#
# Processing Neighborhood:  Crescent Town
# Done:  Crescent Town
#
#
# Processing Neighborhood:  Danforth East
# Done:  Danforth East
#
#
# Processing Neighborhood:  Danforth Station
# Done:  Danforth Station
#
#
# Processing Neighborhood:  Danforth Village
# Done:  Danforth Village
#
#
# Processing Neighborhood:  Danforth by the Valley
# Done:  Danforth by the Valley
#
#
# Processing Neighborhood:  Davenport
# Done:  Davenport
#
#
# Processing Neighborhood:  Davisville
# Done:  Davisville
#
#
# Processing Neighborhood:  Deer Park
# Done:  Deer Park
#
#
# Processing Neighborhood:  Discovery District
# Done:  Discovery District
#
#
# Processing Neighborhood:  Distillery District
# Done:  Distillery District
#
#
# Processing Neighborhood:  Don Mills
# Done:  Don Mills
#
#
# Processing Neighborhood:  Don Vale
# Done:  Don Vale
#
#
# Processing Neighborhood:  Don Valley East
# Done:  Don Valley East
#
#
# Processing Neighborhood:  Don Valley North
# Done:  Don Valley North
#
#
# Processing Neighborhood:  Don Valley Village
# Done:  Don Valley Village
#
#
# Processing Neighborhood:  Don Valley West
# Done:  Don Valley West
#
#
# Processing Neighborhood:  Dorset Park
# Done:  Dorset Park
#
#
# Processing Neighborhood:  Dovercourt
# Done:  Dovercourt
#
#
# Processing Neighborhood:  Downsview
# Done:  Downsview
#
#
# Processing Neighborhood:  Downtown Yonge
# Done:  Downtown Yonge
#
#
# Processing Neighborhood:  Dufferin Grove
# Done:  Dufferin Grove
#
#
# Processing Neighborhood:  Earlscourt
# Done:  Earlscourt
#
#
# Processing Neighborhood:  East End
# Done:  East End
#
#
# Processing Neighborhood:  Eatonville
# Done:  Eatonville
#
#
# Processing Neighborhood:  Eglinton
# Done:  Eglinton
#
#
# Processing Neighborhood:  Eglinton Way
# Done:  Eglinton Way
#
#
# Processing Neighborhood:  Eglinton—Lawrence
# Done:  Eglinton—Lawrence
#
#
# Processing Neighborhood:  Ellesmere
# Done:  Ellesmere
#
#
# Processing Neighborhood:  Emery
# Done:  Emery
#
#
# Processing Neighborhood:  Entertainment District
# Done:  Entertainment District
#
#
# Processing Neighborhood:  Eringate
# Done:  Eringate
#
#
# Processing Neighborhood:  Etobicoke Centre
# Done:  Etobicoke Centre
#
#
# Processing Neighborhood:  Etobicoke North
# Done:  Etobicoke North
#
#
# Processing Neighborhood:  Etobicoke—Lakeshore
# Done:  Etobicoke—Lakeshore
#
#
# Processing Neighborhood:  Fairbank
# Done:  Fairbank
#
#
# Processing Neighborhood:  Fashion District
# Done:  Fashion District
#
#
# Processing Neighborhood:  Financial District
# Done:  Financial District
#
#
# Processing Neighborhood:  First Chinatown
# Done:  First Chinatown
#
#
# Processing Neighborhood:  Fisherville
# Done:  Fisherville
#
#
# Processing Neighborhood:  Flemingdon Park
# Done:  Flemingdon Park
#
#
# Processing Neighborhood:  Forest Hill
# Done:  Forest Hill
#
#
# Processing Neighborhood:  Fort York
# Done:  Fort York
#
#
# Processing Neighborhood:  Garden District
# Done:  Garden District
#
#
# Processing Neighborhood:  German Mills
# Done:  German Mills
#
#
# Processing Neighborhood:  Gerrard India Bazaar
# Done:  Gerrard India Bazaar
#
#
# Processing Neighborhood:  Glen Agar
# Done:  Glen Agar
#
#
# Processing Neighborhood:  Glen Park
# Done:  Glen Park
#
#
# Processing Neighborhood:  Golden Mile
# Done:  Golden Mile
#
#
# Processing Neighborhood:  Guildwood Village
# Done:  Guildwood Village
#
#
# Processing Neighborhood:  Harbord Village
# Done:  Harbord Village
#
#
# Processing Neighborhood:  Harbourfront
# Done:  Harbourfront
#
#
# Processing Neighborhood:  Harwood
# Done:  Harwood
#
#
# Processing Neighborhood:  Henry Farm
# Done:  Henry Farm
#
#
# Processing Neighborhood:  Highfield
# Done:  Highfield
#
#
# Processing Neighborhood:  Highland Creek
# Done:  Highland Creek
#
#
# Processing Neighborhood:  Hillcrest Village
# Done:  Hillcrest Village
#
#
# Processing Neighborhood:  Humber Bay
# Done:  Humber Bay
#
#
# Processing Neighborhood:  Humber Heights
# Done:  Humber Heights
#
#
# Processing Neighborhood:  Humber River—Black Creek
# Done:  Humber River—Black Creek
#
#
# Processing Neighborhood:  Humber Summit
# Done:  Humber Summit
#
#
# Processing Neighborhood:  Humber Valley
# Done:  Humber Valley
#
#
# Processing Neighborhood:  Humberlea
# Done:  Humberlea
#
#
# Processing Neighborhood:  Humberside
# Done:  Humberside
#
#
# Processing Neighborhood:  Humewood
# Done:  Humewood
#
#
# Processing Neighborhood:  Ionview
# Done:  Ionview
#
#
# Processing Neighborhood:  Islington
# Done:  Islington
#
#
# Processing Neighborhood:  Islington Village
# Done:  Islington Village
#
#
# Processing Neighborhood:  Jane & Finch
# Done:  Jane & Finch
#
#
# Processing Neighborhood:  Keelesdale
# Done:  Keelesdale
#
#
# Processing Neighborhood:  Kennedy
# Done:  Kennedy
#
#
# Processing Neighborhood:  Kennedy Park
# Done:  Kennedy Park
#
#
# Processing Neighborhood:  Kensington Market
# Done:  Kensington Market
#
#
# Processing Neighborhood:  King East
# Done:  King East
#
#
# Processing Neighborhood:  King West
# Done:  King West
#
#
# Processing Neighborhood:  Kingsview Village
# Done:  Kingsview Village
#
#
# Processing Neighborhood:  Kipling Heights
# Done:  Kipling Heights
#
#
# Processing Neighborhood:  Koreatown
# Done:  Koreatown
#
#
# Processing Neighborhood:  L'Amoreaux
# Done:  L'Amoreaux
#
#
# Processing Neighborhood:  Lakeshore Village
# Done:  Lakeshore Village
#
#
# Processing Neighborhood:  Lambton
# Done:  Lambton
#
#
# Processing Neighborhood:  Lansing
# Done:  Lansing
#
#
# Processing Neighborhood:  Lawrence Heights
# Done:  Lawrence Heights
#
#
# Processing Neighborhood:  Lawrence Manor
# Done:  Lawrence Manor
#
#
# Processing Neighborhood:  Lawrence Park
# Done:  Lawrence Park
#
#
# Processing Neighborhood:  Leaside
# Done:  Leaside
#
#
# Processing Neighborhood:  Leaside Business Park
# Done:  Leaside Business Park
#
#
# Processing Neighborhood:  Leslieville
# Done:  Leslieville
#
#
# Processing Neighborhood:  Liberty Village
# Done:  Liberty Village
#
#
# Processing Neighborhood:  Little Italy
# Done:  Little Italy
#
#
# Processing Neighborhood:  Little Jamaica
# Done:  Little Jamaica
#
#
# Processing Neighborhood:  Little Malta
# Done:  Little Malta
#
#
# Processing Neighborhood:  Little Portugal
# Done:  Little Portugal
#
#
# Processing Neighborhood:  Little Tibet
# Done:  Little Tibet
#
#
# Processing Neighborhood:  Little Tokyo
# Done:  Little Tokyo
#
#
# Processing Neighborhood:  Long Branch
# Done:  Long Branch
#
#
# Processing Neighborhood:  Lytton Park
# Done:  Lytton Park
#
#
# Processing Neighborhood:  Malvern
# Done:  Malvern
#
#
# Processing Neighborhood:  Malvern West
# Done:  Malvern West
#
#
# Processing Neighborhood:  Maple Leaf
# Done:  Maple Leaf
#
#
# Processing Neighborhood:  Markland Woods
# Done:  Markland Woods
#
#
# Processing Neighborhood:  Martin Grove Gardens
# Done:  Martin Grove Gardens
#
#
# Processing Neighborhood:  Maryvale
# Done:  Maryvale
#
#
# Processing Neighborhood:  Milliken
# Done:  Milliken
#
#
# Processing Neighborhood:  Mimico
# Done:  Mimico
#
#
# Processing Neighborhood:  Mimico By-The-Lake
# Done:  Mimico By-The-Lake
#
#
# Processing Neighborhood:  Mimico Village
# Done:  Mimico Village
#
#
# Processing Neighborhood:  Mirvish Village
# Done:  Mirvish Village
#
#
# Processing Neighborhood:  Moore Park
# Done:  Moore Park
#
#
# Processing Neighborhood:  Morningside
# Done:  Morningside
#
#
# Processing Neighborhood:  Morningside Heights
# Done:  Morningside Heights
#
#
# Processing Neighborhood:  Moss Park
# Done:  Moss Park
#
#
# Processing Neighborhood:  Mount Dennis
# Done:  Mount Dennis
#
#
# Processing Neighborhood:  New Toronto
# Done:  New Toronto
#
#
# Processing Neighborhood:  Newton Brook
# Done:  Newton Brook
#
#
# Processing Neighborhood:  North Park
# Done:  North Park
#
#
# Processing Neighborhood:  North York
# Done:  North York
#
#
# Processing Neighborhood:  Northwood Park
# Done:  Northwood Park
#
#
# Processing Neighborhood:  Oakridge
# Done:  Oakridge
#
#
# Processing Neighborhood:  Oakwood
# Done:  Oakwood
#
#
# Processing Neighborhood:  Old Burnhamthorpe
# Done:  Old Burnhamthorpe
#
#
# Processing Neighborhood:  Old Mill
# Done:  Old Mill
#
#
# Processing Neighborhood:  Olde East York Village
# Done:  Olde East York Village
#
#
# Processing Neighborhood:  Ossington
# Done:  Ossington
#
#
# Processing Neighborhood:  Pape Village
# Done:  Pape Village
#
#
# Processing Neighborhood:  Parkdale
# Done:  Parkdale
#
#
# Processing Neighborhood:  Parkdale—High Park
# Done:  Parkdale—High Park
#
#
# Processing Neighborhood:  Parkview Hills
# Done:  Parkview Hills
#
#
# Processing Neighborhood:  Parkway East
# Done:  Parkway East
#
#
# Processing Neighborhood:  Parkway Forest
# Done:  Parkway Forest
#
#
# Processing Neighborhood:  Parkway West
# Done:  Parkway West
#
#
# Processing Neighborhood:  Pine Point
# Done:  Pine Point
#
#
# Processing Neighborhood:  Pleasant View
# Done:  Pleasant View
#
#
# Processing Neighborhood:  Port Lands
# Done:  Port Lands
#
#
# Processing Neighborhood:  Port Union Village
# Done:  Port Union Village
#
#
# Processing Neighborhood:  Princess Anne Manor
# Done:  Princess Anne Manor
#
#
# Processing Neighborhood:  Princess Margaret
# Done:  Princess Margaret
#
#
# Processing Neighborhood:  Queen West
# Done:  Queen West
#
#
# Processing Neighborhood:  Regent Park
# Done:  Regent Park
#
#
# Processing Neighborhood:  Rexdale
# Done:  Rexdale
#
#
# Processing Neighborhood:  Richview
# Done:  Richview
#
#
# Processing Neighborhood:  Richview Gardens
# Done:  Richview Gardens
#
#
# Processing Neighborhood:  Riverdale
# Done:  Riverdale
#
#
# Processing Neighborhood:  Rogers Road
# Done:  Rogers Road
#
#
# Processing Neighborhood:  Rosedale
# Done:  Rosedale
#
#
# Processing Neighborhood:  Rouge
# Done:  Rouge
#
#
# Processing Neighborhood:  Rouge Hill
# Done:  Rouge Hill
#
#
# Processing Neighborhood:  Rouge Park
# Done:  Rouge Park
#
#
# Processing Neighborhood:  Runnymede
# Done:  Runnymede
#
#
# Processing Neighborhood:  STEELES AVE E
# Done:  STEELES AVE E
#
#
# Processing Neighborhood:  STEELES AVE W
# Done:  STEELES AVE W
#
#
# Processing Neighborhood:  Scarborough Centre
# Done:  Scarborough Centre
#
#
# Processing Neighborhood:  Scarborough Junction
# Done:  Scarborough Junction
#
#
# Processing Neighborhood:  Scarborough North
# Done:  Scarborough North
#
#
# Processing Neighborhood:  Scarborough Southwest
# Done:  Scarborough Southwest
#
#
# Processing Neighborhood:  Scarborough Village
# Done:  Scarborough Village
#
#
# Processing Neighborhood:  Scarborough—Agincourt
# Done:  Scarborough—Agincourt
#
#
# Processing Neighborhood:  Scarborough—Guildwood
# Done:  Scarborough—Guildwood
#
#
# Processing Neighborhood:  Scarborough—Rouge Park
# Done:  Scarborough—Rouge Park
#
#
# Processing Neighborhood:  Seaton Village
# Done:  Seaton Village
#
#
# Processing Neighborhood:  Sherwood Park
# Done:  Sherwood Park
#
#
# Processing Neighborhood:  Silver Hills
# Done:  Silver Hills
#
#
# Processing Neighborhood:  Silverthorn
# Done:  Silverthorn
#
#
# Processing Neighborhood:  Six Points
# Done:  Six Points
#
#
# Processing Neighborhood:  South Core
# Done:  South Core
#
#
# Processing Neighborhood:  South Hill
# Done:  South Hill
#
#
# Processing Neighborhood:  Spadina—Fort York
# Done:  Spadina—Fort York
#
#
# Processing Neighborhood:  St. Clair West
# Done:  St. Clair West
#
#
# Processing Neighborhood:  St. James Town
# Done:  St. James Town
#
#
# Processing Neighborhood:  St. John
# Done:  St. John
#
#
# Processing Neighborhood:  St. Lawrence
# Done:  St. Lawrence
#
#
# Processing Neighborhood:  St. Phillips
# Done:  St. Phillips
#
#
# Processing Neighborhood:  Steeles
# Done:  Steeles
#
#
# Processing Neighborhood:  Sullivan
# Done:  Sullivan
#
#
# Processing Neighborhood:  Tam O'Shanter
# Done:  Tam O'Shanter
#
#
# Processing Neighborhood:  Tarragon Village
# Done:  Tarragon Village
#
#
# Processing Neighborhood:  The Annex
# Done:  The Annex
#
#
# Processing Neighborhood:  The Beaches
# Done:  The Beaches
#
#
# Processing Neighborhood:  The Bridle Path
# Done:  The Bridle Path
#
#
# Processing Neighborhood:  The Kingsway
# Done:  The Kingsway
#
#
# Processing Neighborhood:  The Lakeshore Grounds
# Done:  The Lakeshore Grounds
#
#
# Processing Neighborhood:  The Peanut
# Done:  The Peanut
#
#
# Processing Neighborhood:  The Queensway
# Done:  The Queensway
#
#
# Processing Neighborhood:  Thistletown
# Done:  Thistletown
#
#
# Processing Neighborhood:  Thorncliffe Park
# Done:  Thorncliffe Park
#
#
# Processing Neighborhood:  Thorncrest Village
# Done:  Thorncrest Village
#
#
# Processing Neighborhood:  Thornlea
# Done:  Thornlea
#
#
# Processing Neighborhood:  Todmorden Village
# Done:  Todmorden Village
#
#
# Processing Neighborhood:  Toronto Centre
# Done:  Toronto Centre
#
#
# Processing Neighborhood:  Toronto—Danforth
# Done:  Toronto—Danforth
#
#
# Processing Neighborhood:  Toronto—St. Paul's
# Done:  Toronto—St. Paul's
#
#
# Processing Neighborhood:  Trefann Court
# Done:  Trefann Court
#
#
# Processing Neighborhood:  University—Rosedale
# Done:  University—Rosedale
#
#
# Processing Neighborhood:  Upper Guild
# Done:  Upper Guild
#
#
# Processing Neighborhood:  Vaughan Corporate Centre
# Done:  Vaughan Corporate Centre
#
#
# Processing Neighborhood:  Victoria Village
# Done:  Victoria Village
#
#
# Processing Neighborhood:  Wallace Emerson
# Done:  Wallace Emerson
#
#
# Processing Neighborhood:  Warren Park
# Done:  Warren Park
#
#
# Processing Neighborhood:  West Deane Park
# Done:  West Deane Park
#
#
# Processing Neighborhood:  West Hill
# Done:  West Hill
#
#
# Processing Neighborhood:  West Humber Estates
# Done:  West Humber Estates
#
#
# Processing Neighborhood:  West Queen West
# Done:  West Queen West
#
#
# Processing Neighborhood:  West Rouge
# Done:  West Rouge
#
#
# Processing Neighborhood:  Westmount
# Done:  Westmount
#
#
# Processing Neighborhood:  Weston
# Done:  Weston
#
#
# Processing Neighborhood:  Wexford
# Done:  Wexford
#
#
# Processing Neighborhood:  Wexford Heights
# Done:  Wexford Heights
#
#
# Processing Neighborhood:  William Baker
# Done:  William Baker
#
#
# Processing Neighborhood:  Willowdale
# Done:  Willowdale
#
#
# Processing Neighborhood:  Wilson Heights
# Done:  Wilson Heights
#
#
# Processing Neighborhood:  Winston Park
# Done:  Winston Park
#
#
# Processing Neighborhood:  Woburn
# Done:  Woburn
#
#
# Processing Neighborhood:  Woodbine Gardens
# Done:  Woodbine Gardens
#
#
# Processing Neighborhood:  Woodbine Heights
# Done:  Woodbine Heights
#
#
# Processing Neighborhood:  Wynford
# Done:  Wynford
#
#
# Processing Neighborhood:  YONGE ST
# Done:  YONGE ST
#
#
# Processing Neighborhood:  Yonge & Eglinton
# Done:  Yonge & Eglinton
#
#
# Processing Neighborhood:  York Centre
# Done:  York Centre
#
#
# Processing Neighborhood:  York Heights
# Done:  York Heights
#
#
# Processing Neighborhood:  York Mills
# Done:  York Mills
#
#
# Processing Neighborhood:  York South—Weston
# Done:  York South—Weston
#
#
# Processing Neighborhood:  Yorkville
# Done:  Yorkville

# %% [markdown]
# Filering out only the competitors and finding out the number of competitors in each neighborhood

# %%
blacklist = ['Fast Food Restaurant', 'Burrito Place', 'Pizza Place', 'Fried Chicken Joint', 'Wings Joint', 'Taco Place', 'Food Court', 'Burger Joint', 'BBQ Joint', 'Mac & Cheese Joint']
venues = toronto_venues[toronto_venues['Venue Category'].isin(blacklist)]

# %%
one_hot_venues = pd.get_dummies(venues['Venue Category'])
one_hot_venues['competitions'] = one_hot_venues.sum(axis=1)

one_hot_venues['neighborhood'] = venues['Neighborhood']

# %%
compete = one_hot_venues.groupby('neighborhood').sum()
compete = compete.reset_index()
compete = compete[['neighborhood', 'competitions']]

# %%
compete.head()
# Out:
#        neighborhood  competitions
# 0  Agincourt Centre             5
# 1   Agincourt North             5
# 2    Alexandra Park             6
# 3          Armadale             4
# 4   Bayview Village             1

# %% [markdown]
# Adding the number of competitors to pedestrian volume dataframe and setting those having no competition to 0

# %%
merged_df = df_grouped.join(compete.set_index('neighborhood'), on='neighborhood')
merged_df = merged_df.replace(np.nan, 0)

# %%
merged_df.head()
# Out:
#        neighborhood   latitude  longitude  pedestrian_volume  \
# 0         Agincourt  43.794101 -79.282192               1104
# 1  Agincourt Centre  43.781529 -79.288070               7958
# 2   Agincourt North  43.808548 -79.270792              17440
# 3         Alderwood  43.611252 -79.546050               3545
# 4    Alexandra Park  43.648064 -79.404321              13032
#
#    pedestrian_volume_normalised  competitions
# 0                      0.004125           0.0
# 1                      0.029731           5.0
# 2                      0.065156           5.0
# 3                      0.013244           0.0
# 4                      0.048687           6.0

# %% [markdown]
# Finding out outliers in the competition

# %%
merged_df['competitions'].plot(kind='box')
plt.show()

# %% [markdown]
# Printing place with maximum number of competitions (We are obviously not considering this place for opening)

# %%
merged_df[merged_df['competitions'] == merged_df.competitions.max()]
# Out:
#               neighborhood   latitude  longitude  pedestrian_volume  \
# 76  Entertainment District  43.647398 -79.388537             267667
#
#     pedestrian_volume_normalised  competitions
# 76                           1.0          10.0

# %%
merged_df.describe()
# Out:
#          latitude   longitude  pedestrian_volume  \
# count  268.000000  268.000000         268.000000
# mean    43.705675  -79.384901       16930.932836
# std      0.055046    0.209985       32877.567283
# min     43.592941  -79.601589           4.000000
# 25%     43.661648  -79.474710        3407.500000
# 50%     43.695117  -79.395048        6796.000000
# 75%     43.749088  -79.326056       15661.000000
# max     43.842590  -76.404853      267667.000000
#
#        pedestrian_volume_normalised  competitions
# count                    268.000000    268.000000
# mean                       0.063254      1.798507
# std                        0.122830      2.113909
# min                        0.000015      0.000000
# 25%                        0.012730      0.000000
# 50%                        0.025390      1.000000
# 75%                        0.058509      3.000000
# max                        1.000000     10.000000

# %% [markdown]
# 75% of the pedestrian volume is smaller than 15661, so we are setting the threshold for pedestrian volume at <b>15000 or more persons per day.</b>
# We can also observe that around 75% of the places have less than 3 places in competition with our type of restaurant, so we can set a threshold of <b>3 or less competitions.</b>

# %%
recommended_df = merged_df[merged_df['competitions'] < 4]
recommended_df = recommended_df[recommended_df['pedestrian_volume'] > 15000]

# %%
recommended_df = recommended_df.sort_values('pedestrian_volume', ascending=False)
recommended_df.reset_index(inplace=True, drop=True)
recommended_df = recommended_df.head(20)

# %% [markdown]
# Visualizing the recommendations on map (Red to Violet -> Most to Least recommended)

# %%
recommended_map = folium.Map(location=[t_latitude, t_longitude], zoom_start=11)

colors_array = cm.rainbow(np.linspace(0, 1, len(recommended_df['pedestrian_volume_normalised'])))
rainbow = [colors.rgb2hex(i) for i in colors_array]
rainbow = rainbow[::-1]

for lat, lng, neigh, vol, comp, color in zip(recommended_df['latitude'], recommended_df['longitude'], recommended_df['neighborhood'], recommended_df['pedestrian_volume'], recommended_df['competitions'], rainbow):
    label = folium.Popup(str(neigh) + "\nComp: " + str(comp) + "\nPeople: " + str(vol), parse_html=True)
    folium.CircleMarker(
    [lat, lng],
    popup=label,
    color=color,
    radius=5,
    fill=True,
    fill_color=color,
    fill_opacity=0.5).add_to(recommended_map)
    
recommended_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
recommended_df
# Out:
#                      neighborhood   latitude  longitude  pedestrian_volume  \
# 0                       Yorkville  43.672921 -79.387936             163569
# 1                       King East  43.650648 -79.375515             141290
# 2   Bloor Street Culture Corridor  43.667084 -79.395838             126610
# 3              Discovery District  43.658712 -79.389269             105377
# 4                         Lansing  43.766599 -79.417980              89758
# 5             University—Rosedale  43.671521 -79.392458              62323
# 6              Parkdale—High Park  43.650713 -79.460926              55316
# 7                      South Core  43.642590 -79.375996              43763
# 8                       The Annex  43.667669 -79.404026              40854
# 9                    Jane & Finch  43.760842 -79.515553              40555
# 10                       Parkdale  43.639911 -79.435628              40246
# 11                   Newton Brook  43.786273 -79.411186              39626
# 12                Little Portugal  43.649754 -79.431259              34804
# 13                   Pape Village  43.685209 -79.344980              33514
# 14              Eglinton—Lawrence  43.715803 -79.418271              31589
# 15               Danforth Village  43.683629 -79.320335              28120
# 16                         Woburn  43.763181 -79.227337              27327
# 17                         Weston  43.701451 -79.511118              26095
# 18                   Corso Italia  43.677212 -79.441889              25438
# 19                     Dovercourt  43.665588 -79.433132              24750
#
#     pedestrian_volume_normalised  competitions
# 0                       0.611091           3.0
# 1                       0.527857           3.0
# 2                       0.473013           1.0
# 3                       0.393687           2.0
# 4                       0.335335           1.0
# 5                       0.232838           2.0
# 6                       0.206660           1.0
# 7                       0.163498           1.0
# 8                       0.152630           2.0
# 9                       0.151513           2.0
# 10                      0.150358           2.0
# 11                      0.148042           0.0
# 12                      0.130027           1.0
# 13                      0.125208           2.0
# 14                      0.118016           0.0
# 15                      0.105056           2.0
# 16                      0.102093           3.0
# 17                      0.097491           0.0
# 18                      0.095036           1.0
# 19                      0.092466           0.0
